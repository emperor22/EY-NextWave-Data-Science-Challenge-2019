# %%
#train_without_same合并训练集和测试集
import numpy as np 
import pandas as pd

# %%
tra = pd.DataFrame(pd.read_csv('train_with_new_features.csv'))
tst = pd.DataFrame(pd.read_csv('test_with_new_features.csv'))

# %%
tra.head(7)
# Out:
#                                trajectory_id time_entry time_exit  \
# 0  traj_0000a8602cf2def930488dee7cdad104_1_0   07:04:31  07:08:32
# 1  traj_0000a8602cf2def930488dee7cdad104_1_1   07:20:34  07:25:42
# 2  traj_0000a8602cf2def930488dee7cdad104_1_2   07:53:32  08:03:25
# 3  traj_0000a8602cf2def930488dee7cdad104_1_3   08:17:50  08:37:23
# 4  traj_0000a8602cf2def930488dee7cdad104_1_4   14:38:09  14:38:09
# 5  traj_0000a8602cf2def930488dee7cdad104_1_5   15:02:31  15:18:33
# 6  traj_0000cf177130469eeac79f67b6bcf3df_9_0   14:29:23  14:29:23
#
#         x_entry       y_entry        x_exit        y_exit  time_interval  \
# 0  3.751014e+06 -1.909398e+07  3.750326e+06 -1.913634e+07            241
# 1  3.743937e+06 -1.932247e+07  3.744975e+06 -1.931966e+07            308
# 2  3.744868e+06 -1.929356e+07  3.744816e+06 -1.929284e+07            593
# 3  3.744880e+06 -1.929229e+07  3.744809e+06 -1.929049e+07           1173
# ...

# %%
sameTime=(tra['time_entry'] == tra['time_exit'])
tra['sameTime']=sameTime

# %%
#tra=tra.drop(['hash','center'], axis=1)#0删除行，1删除列
tra1=tra[ tra['sameTime'] == False ]

# %%
tra1.head(7)
# Out:
#                                 trajectory_id time_entry time_exit  \
# 0   traj_0000a8602cf2def930488dee7cdad104_1_0   07:04:31  07:08:32
# 1   traj_0000a8602cf2def930488dee7cdad104_1_1   07:20:34  07:25:42
# 2   traj_0000a8602cf2def930488dee7cdad104_1_2   07:53:32  08:03:25
# 3   traj_0000a8602cf2def930488dee7cdad104_1_3   08:17:50  08:37:23
# 5   traj_0000a8602cf2def930488dee7cdad104_1_5   15:02:31  15:18:33
# 9   traj_0000cf177130469eeac79f67b6bcf3df_9_3   15:00:32  15:29:48
# 10  traj_0001f97b99a80f18f62e2d44e54ef33d_3_0   11:37:06  11:52:08
#
#          x_entry       y_entry        x_exit        y_exit  time_interval  \
# 0   3.751014e+06 -1.909398e+07  3.750326e+06 -1.913634e+07            241
# 1   3.743937e+06 -1.932247e+07  3.744975e+06 -1.931966e+07            308
# 2   3.744868e+06 -1.929356e+07  3.744816e+06 -1.929284e+07            593
# 3   3.744880e+06 -1.929229e+07  3.744809e+06 -1.929049e+07           1173
# ...

# %%
tra1=tra1.drop(columns=['center','sameTime'], axis=1)

# %%
tra1['center']=np.nan

# %%
tra1.to_csv("tra1.csv",index=False,sep=',')

# %%
tst1.head(17)
# Out:
#                                   trajectory_id time_entry time_exit  \
# 0    traj_00032f51796fd5437b238e3a9823d13d_31_0   11:43:17  11:50:17
# 2    traj_00032f51796fd5437b238e3a9823d13d_31_3   12:34:27  13:14:11
# 3    traj_00032f51796fd5437b238e3a9823d13d_31_4   13:25:33  13:43:13
# 4    traj_00032f51796fd5437b238e3a9823d13d_31_5   15:03:32  15:10:32
# 5    traj_000479418b5561ab694a2870cc04fd43_25_0   08:08:23  08:20:08
# 6    traj_000479418b5561ab694a2870cc04fd43_25_6   12:08:23  12:13:24
# 7   traj_000479418b5561ab694a2870cc04fd43_25_10   15:29:09  15:30:56
# 8    traj_000506a39775e5bca661ac80e3f466eb_29_1   08:45:05  08:50:33
# 13    traj_0005401ceddaf27a9b7f0d42ef1fbe95_1_4   15:35:18  15:42:05
# 14    traj_00063a4f6c12e1e4de7d876580620667_3_1   08:48:38  09:33:56
# 15    traj_00063a4f6c12e1e4de7d876580620667_3_2   12:53:38  12:58:19
# 16    traj_00063a4f6c12e1e4de7d876580620667_3_3   14:18:20  14:35:02
# 17    traj_00063a4f6c12e1e4de7d876580620667_3_4   14:54:07  15:05:14
# ...

# %%
tst = pd.DataFrame(pd.read_csv('test_with_new_features.csv'))

# %%
tst1=tst[ tst['time_interval'] != 0 ]

# %%
e=[]
e=pd.isnull(tst['x_exit'])

# %%
tst1['e']=e
# Out:
# /Users/YAO/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
tst1=tst1[ tst1['e'] == False ]

# %%
tst1.head(17)
# Out:
#                                  trajectory_id time_entry time_exit  \
# 0   traj_00032f51796fd5437b238e3a9823d13d_31_0   11:43:17  11:50:17
# 2   traj_00032f51796fd5437b238e3a9823d13d_31_3   12:34:27  13:14:11
# 3   traj_00032f51796fd5437b238e3a9823d13d_31_4   13:25:33  13:43:13
# 5   traj_000479418b5561ab694a2870cc04fd43_25_0   08:08:23  08:20:08
# 6   traj_000479418b5561ab694a2870cc04fd43_25_6   12:08:23  12:13:24
# 8   traj_000506a39775e5bca661ac80e3f466eb_29_1   08:45:05  08:50:33
# 14   traj_00063a4f6c12e1e4de7d876580620667_3_1   08:48:38  09:33:56
# 15   traj_00063a4f6c12e1e4de7d876580620667_3_2   12:53:38  12:58:19
# 16   traj_00063a4f6c12e1e4de7d876580620667_3_3   14:18:20  14:35:02
# 24  traj_0006f84bb33ec929d1cda7686f861d0a_31_0   12:01:39  12:09:32
# 32  traj_000c739e444a70e1804d757a0580caaa_31_0   11:21:19  11:42:15
# 35  traj_000d479078af08618bddc7f09082b8c3_11_0   13:42:32  13:55:10
# 38  traj_000d479078af08618bddc7f09082b8c3_11_4   14:35:59  14:57:06
# ...

# %%
tst1=tst1.drop(columns=['e'], axis=1)

# %%
tra = pd.DataFrame(pd.read_csv('tra1.csv'))

# %%
tra['ee']=((tra['x_exit']>=3750901.5068) & (tra['x_exit']<=3770901.5068)) & ((tra['y_exit']>=-19268905.6133) & (tra['y_exit']<=-19208905.6133))

# %%
e=[]
for row in tra.itertuples(index=True, name='Pandas'):
    if getattr(row, "ee"):
        e.append(1)
    else:
        e.append(0)
tra['center']=e

# %%
tra=tra.drop(columns=['ee'], axis=1)

# %%
tra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381185 entries, 0 to 381184
# Data columns (total 10 columns):
# trajectory_id    381185 non-null object
# time_entry       381185 non-null object
# time_exit        381185 non-null object
# x_entry          381185 non-null float64
# y_entry          381185 non-null float64
# x_exit           381185 non-null float64
# y_exit           381185 non-null float64
# time_interval    381185 non-null int64
# distance         381185 non-null float64
# center           381185 non-null int64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 29.1+ MB

# %%
tra.to_csv("tra1.csv",index=False,sep=',')
