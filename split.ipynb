# %%
import numpy as np 
import pandas as pd

# %%
train = pd.read_csv('train_with_new_features.csv')
test = pd.read_csv('test_with_new_features.csv')

# %%
tra=pd.DataFrame(train)
tst=pd.DataFrame(test)

# %%
tst1=pd.DataFrame(pd.read_csv('test_without_sametime.csv'))

# %%
tst1.head(7)
# Out:
#                                   hash  \
# 0  00032f51796fd5437b238e3a9823d13d_31
# 1  00032f51796fd5437b238e3a9823d13d_31
# 2  00032f51796fd5437b238e3a9823d13d_31
# 3  00032f51796fd5437b238e3a9823d13d_31
# 4  00032f51796fd5437b238e3a9823d13d_31
# 5  000479418b5561ab694a2870cc04fd43_25
# 6  000479418b5561ab694a2870cc04fd43_25
#
#                                 trajectory_id time_entry time_exit   vmax  \
# 0  traj_00032f51796fd5437b238e3a9823d13d_31_0   11:43:17  11:50:17    NaN
# 1  traj_00032f51796fd5437b238e3a9823d13d_31_2   12:21:37  12:21:37   0.00
# 2  traj_00032f51796fd5437b238e3a9823d13d_31_3   12:34:27  13:14:11    NaN
# 3  traj_00032f51796fd5437b238e3a9823d13d_31_4   13:25:33  13:43:13    NaN
# 4  traj_00032f51796fd5437b238e3a9823d13d_31_5   15:03:32  15:10:32    NaN
# 5  traj_000479418b5561ab694a2870cc04fd43_25_0   08:08:23  08:20:08  17.29
# 6  traj_000479418b5561ab694a2870cc04fd43_25_6   12:08:23  12:13:24    NaN
#
# ...

# %%
tst['hash']=tst1['hash']

# %%
tst.head(7)
# Out:
#                                 trajectory_id time_entry time_exit  \
# 0  traj_00032f51796fd5437b238e3a9823d13d_31_0   11:43:17  11:50:17
# 1  traj_00032f51796fd5437b238e3a9823d13d_31_2   12:21:37  12:21:37
# 2  traj_00032f51796fd5437b238e3a9823d13d_31_3   12:34:27  13:14:11
# 3  traj_00032f51796fd5437b238e3a9823d13d_31_4   13:25:33  13:43:13
# 4  traj_00032f51796fd5437b238e3a9823d13d_31_5   15:03:32  15:10:32
# 5  traj_000479418b5561ab694a2870cc04fd43_25_0   08:08:23  08:20:08
# 6  traj_000479418b5561ab694a2870cc04fd43_25_6   12:08:23  12:13:24
#
#         x_entry       y_entry        x_exit        y_exit  time_interval  \
# 0  3.773413e+06 -1.909828e+07  3.773111e+06 -1.914508e+07            420
# 1  3.773199e+06 -1.914354e+07  3.773199e+06 -1.914354e+07              0
# 2  3.763760e+06 -1.921342e+07  3.771757e+06 -1.911092e+07           2384
# 3  3.773385e+06 -1.911344e+07  3.773131e+06 -1.914465e+07           1060
# ...

# %%
tst['e']=np.nan

# %%
tst=tst.drop_duplicates(subset='hash', keep='last', inplace=False)

# %%
tst.head(7)
# Out:
#                                   trajectory_id time_entry time_exit  \
# 4    traj_00032f51796fd5437b238e3a9823d13d_31_5   15:03:32  15:10:32
# 7   traj_000479418b5561ab694a2870cc04fd43_25_10   15:29:09  15:30:56
# 10   traj_000506a39775e5bca661ac80e3f466eb_29_5   15:26:08  15:26:08
# 13    traj_0005401ceddaf27a9b7f0d42ef1fbe95_1_4   15:35:18  15:42:05
# 17    traj_00063a4f6c12e1e4de7d876580620667_3_4   14:54:07  15:05:14
# 23   traj_0006535be25bb52dd06983447880c964_5_12   15:22:06  15:22:06
# 27   traj_0006f84bb33ec929d1cda7686f861d0a_31_3   15:00:12  15:00:12
#
#          x_entry       y_entry        x_exit        y_exit  time_interval  \
# 4   3.773118e+06 -1.914490e+07           NaN           NaN            420
# 7   3.769978e+06 -1.934136e+07           NaN           NaN            107
# 10  3.757468e+06 -1.923860e+07  3.757468e+06 -1.923860e+07              0
# 13  3.760505e+06 -1.935500e+07           NaN           NaN            407
# ...

# %%
tst=tst.drop(['hash','center'], axis=1)
tst = tst.rename(columns={'e': 'center'})

# %%
tst.to_csv("all_null_center.csv",index=False,sep=',')

# %% [raw]
# ## 删除行

# %%
test = pd.read_csv('test_with_new_features.csv')
tst=pd.DataFrame(test)

# %%
tst.head(7)
# Out:
#                                 trajectory_id time_entry time_exit  \
# 0  traj_00032f51796fd5437b238e3a9823d13d_31_0   11:43:17  11:50:17
# 1  traj_00032f51796fd5437b238e3a9823d13d_31_2   12:21:37  12:21:37
# 2  traj_00032f51796fd5437b238e3a9823d13d_31_3   12:34:27  13:14:11
# 3  traj_00032f51796fd5437b238e3a9823d13d_31_4   13:25:33  13:43:13
# 4  traj_00032f51796fd5437b238e3a9823d13d_31_5   15:03:32  15:10:32
# 5  traj_000479418b5561ab694a2870cc04fd43_25_0   08:08:23  08:20:08
# 6  traj_000479418b5561ab694a2870cc04fd43_25_6   12:08:23  12:13:24
#
#         x_entry       y_entry        x_exit        y_exit  time_interval  \
# 0  3.773413e+06 -1.909828e+07  3.773111e+06 -1.914508e+07            420
# 1  3.773199e+06 -1.914354e+07  3.773199e+06 -1.914354e+07              0
# 2  3.763760e+06 -1.921342e+07  3.771757e+06 -1.911092e+07           2384
# 3  3.773385e+06 -1.911344e+07  3.773131e+06 -1.914465e+07           1060
# ...

# %%
tst1=pd.DataFrame(pd.read_csv('test_without_sametime.csv'))

# %%
tst1.head(7)
# Out:
#                                   hash  \
# 0  00032f51796fd5437b238e3a9823d13d_31
# 1  00032f51796fd5437b238e3a9823d13d_31
# 2  00032f51796fd5437b238e3a9823d13d_31
# 3  00032f51796fd5437b238e3a9823d13d_31
# 4  00032f51796fd5437b238e3a9823d13d_31
# 5  000479418b5561ab694a2870cc04fd43_25
# 6  000479418b5561ab694a2870cc04fd43_25
#
#                                 trajectory_id time_entry time_exit   vmax  \
# 0  traj_00032f51796fd5437b238e3a9823d13d_31_0   11:43:17  11:50:17    NaN
# 1  traj_00032f51796fd5437b238e3a9823d13d_31_2   12:21:37  12:21:37   0.00
# 2  traj_00032f51796fd5437b238e3a9823d13d_31_3   12:34:27  13:14:11    NaN
# 3  traj_00032f51796fd5437b238e3a9823d13d_31_4   13:25:33  13:43:13    NaN
# 4  traj_00032f51796fd5437b238e3a9823d13d_31_5   15:03:32  15:10:32    NaN
# 5  traj_000479418b5561ab694a2870cc04fd43_25_0   08:08:23  08:20:08  17.29
# 6  traj_000479418b5561ab694a2870cc04fd43_25_6   12:08:23  12:13:24    NaN
#
# ...

# %%
tst1['y_exit']==NaN
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-ea8f3c29ff2f> in <module>
# ----> 1 tst1['y_exit']==NaN
#
# NameError: name 'NaN' is not defined

# %%
e=[]
i=0
for row in tst1.itertuples(index=True, name='Pandas'):
    if getattr(row, "sameTime") & getattr(row, "y_exit"):
        e.append(1)
    else:
        e.append(0)
